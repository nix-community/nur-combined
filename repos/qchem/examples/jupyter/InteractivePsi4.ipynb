# %%
import psi4
import matplotlib.pyplot as plt
import numpy as np

# %%
# Taken from the Psi4 manual:
#! Example potential energy surface scan and CP-correction for Ne2

ne2_geometry = """
Ne
--
Ne 1 {0}
"""

Rvals = np.arange(2.5,4.1,0.25)

psi4.set_options({'freeze_core': 'true'})

# Initialize a blank dictionary of counterpoise corrected energies
# (Need this for the syntax below to work)

ecp = {}

for R in Rvals:
    ne2 = psi4.geometry(ne2_geometry.format(R))
    ecp[R] = psi4.energy('ccsd(t)/aug-cc-pvdz', bsse_type='cp', molecule=ne2)
# Out:
# Scratch directory: /tmp/
#
#
#    ===> N-Body Interaction Abacus <===
#         BSSE Treatment:                     cp
#         Number of 1-body computations:     2
#         Number of 2-body computations:     1
#
#    ==> N-Body: Now computing 1-body complexes <==
#
#
#        N-Body: Computing complex (1/2) with fragments (2,) in the basis of fragments (1, 2).
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
#
# *** tstart() called on rlyeh
# *** at Fri Sep 24 12:58:02 2021
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry NE         line   326 file /nix/store/rg166scwkb8v2jqk5yy7pmxfn5ywfm07-python3.9-psi4-1.4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2v
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#       Gh(NE)          0.000000000000     0.000000000000    -1.250000000000    19.992440176200
#          NE           0.000000000000     0.000000000000     1.250000000000    19.992440176200
#
#   Running in c2v symmetry.
#
#   Rotational constants: A = ************  B =      0.26982  C =      0.26982 [cm^-1]
#   Rotational constants: A = ************  B =   8089.12176  C =   8089.12176 [MHz]
#   Nuclear repulsion =    0.000000000000000
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 18
#     Number of basis functions: 46
#     Number of Cartesian functions: 50
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              18
#       Number of primitives:             50
#       Number of atomic orbitals:        50
#       Number of basis functions:        46
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 1169642 doubles for integral storage.
#   We computed 14293 shell quartets total.
#   Whereas there are 14706 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 4.9925438186E-02.
#   Reciprocal condition number of the overlap matrix is 1.8240897792E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A1        22      22
#      A2         4       4
#      B1        10      10
#      B2        10      10
#    -------------------------
#     Total      46      46
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:  -128.49634722923207   -1.28496e+02   0.00000e+00
#    @RHF iter   1:  -128.49643645752948   -8.92283e-05   8.30689e-05 DIIS
#    @RHF iter   2:  -128.49643822809387   -1.77056e-06   2.89618e-05 DIIS
#    @RHF iter   3:  -128.49643838180108   -1.53707e-07   6.56837e-06 DIIS
#    @RHF iter   4:  -128.49643839196614   -1.01651e-08   3.46539e-07 DIIS
#    @RHF iter   5:  -128.49643839202432   -5.81792e-11   3.11884e-08 DIIS
#    @RHF iter   6:  -128.49643839202471   -3.97904e-13   5.10887e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A1   -32.794999     2A1    -1.940396     3A1    -0.853000
#        1B1    -0.852986     1B2    -0.852986
#
#     Virtual:
#
#        4A1     0.163586     2B2     0.242152     2B1     0.242152
#        5A1     0.248883     6A1     0.323039     3B1     0.332037
#        3B2     0.332037     7A1     0.493003     8A1     1.082205
#        4B2     1.312813     4B1     1.312813     9A1     1.319752
#       10A1     1.752522    11A1     1.757686     1A2     1.757686
#        5B2     1.761285     5B1     1.761285     6B2     1.968421
#        6B1     1.968421    12A1     1.976849     2A2     2.123769
#       13A1     2.123769     7B1     2.141738     7B2     2.141738
#       14A1     2.295077    15A1     2.845273    16A1     4.704755
#        3A2     6.372541    17A1     6.372541     8B1     6.378208
#        8B2     6.378208    18A1     6.421934     9B1     8.947897
#        9B2     8.947897     4A2     8.956409    19A1     8.956409
#       10B1     8.965727    10B2     8.965727    20A1     8.975407
#       21A1     9.018394    22A1    53.421735
#
#     Final Occupation by Irrep:
#              A1    A2    B1    B2
#     DOCC [     3,    0,    1,    1 ]
#
#   @RHF Final Energy:  -128.49643839202471
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.0000000000000000
#     One-Electron Energy =                -182.4041421771295575
#     Two-Electron Energy =                  53.9077037851048431
#     Total Energy =                       -128.4964383920247144
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    23.6216
#
#   Electronic Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:   -23.6196
#
#   Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:     0.0019     Total:     0.0019
#
#   Dipole Moment: [D]
#      X:     0.0000      Y:     0.0000      Z:     0.0049     Total:     0.0049
#
#
# *** tstop() called on rlyeh at Fri Sep 24 12:58:02 2021
# Module time:
# 	user time   =       0.25 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       5.57 seconds =       0.09 minutes
# 	system time =       2.32 seconds =       0.04 minutes
# 	total time  =        402 seconds =       6.70 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              18
#       Number of SO shells:              18
#       Number of primitives:             50
#       Number of atomic orbitals:        50
#       Number of basis functions:        46
#
#       Number of irreps:                  4
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  22    4   10   10 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 118972 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on rlyeh
# *** at Fri Sep 24 12:58:02 2021
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 4
# 	Number of MOs        = 46
# 	Number of active MOs = 45
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = RHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 A1	   22	    1	    2	    0	    19	    0
# 	 A2	   4	    0	    0	    0	    4	    0
# 	 B1	   10	    0	    1	    0	    9	    0
# 	 B2	   10	    0	    1	    0	    9	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =    -93.84889482771588
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.291 (MW) /      2.324 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.099 (MW) /      0.789 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.171 (MW) /      1.371 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.171 (MW) /      1.371 (MB)
# 	Total:                                     0.732 (MW) /      5.855 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.030 (MW) /      0.241 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.008 (MW) /      0.065 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.017 (MW) /      0.136 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.017 (MW) /      0.136 (MB)
# 	Total:                                     0.072 (MW) /      0.578 (MB)
#
# 	Size of irrep 0 of tijab amplitudes:       0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of tijab amplitudes:       0.001 (MW) /      0.005 (MB)
# 	Size of irrep 2 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Total:                                     0.007 (MW) /      0.057 (MB)
#
# 	Nuclear Rep. energy          =      0.00000000000000
# 	SCF energy                   =   -128.49643839202471
# 	One-electron energy          =    -60.29634956360998
# 	Two-electron energy          =     25.64880599930120
# 	Reference energy             =   -128.49643839202466
#
# *** tstop() called on rlyeh at Fri Sep 24 12:58:02 2021
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.07 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       5.72 seconds =       0.10 minutes
# 	system time =       2.39 seconds =       0.04 minutes
# 	total time  =        402 seconds =       6.70 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =    0.000000000000000
#     SCF energy          (wfn)     = -128.496438392024714
#     Reference energy    (file100) = -128.496438392024658
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     RHF
#     Brueckner       =     No
#     Memory (Mbytes) =     524.3
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LOW
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.2069305972867176
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.206930597286718    0.000e+00    0.000000    0.000000    0.000000    0.082908
#      1        -0.207285299678084    2.745e-02    0.008612    0.013707    0.013707    0.083772
#      2        -0.209745655537151    7.158e-03    0.008273    0.013048    0.013048    0.085846
#      3        -0.210268981648079    2.789e-03    0.009277    0.014651    0.014651    0.086515
#      4        -0.210229328622421    3.565e-04    0.009387    0.014827    0.014827    0.086545
#      5        -0.210219912534433    8.554e-05    0.009406    0.014860    0.014860    0.086540
#      6        -0.210219561015233    2.015e-05    0.009410    0.014868    0.014868    0.086539
#      7        -0.210219318916591    6.022e-06    0.009411    0.014870    0.014870    0.086538
#      8        -0.210219215483385    1.220e-06    0.009411    0.014870    0.014870    0.086538
#      9        -0.210219206702631    2.695e-07    0.009411    0.014870    0.014870    0.086538
#     10        -0.210219203293846    6.279e-08    0.009411    0.014870    0.014870    0.086538
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#               1   2        -0.0125301020
#               2  24        -0.0115227303
#               3  33        -0.0115227303
#               2  23         0.0088876790
#               3  32         0.0088876790
#               1   0         0.0055067038
#               0   1        -0.0050988277
#               0   3         0.0038389936
#               1   3        -0.0038296769
#               1   1        -0.0031155877
#
#     Largest TIjAb Amplitudes:
#       2   2  27  27        -0.0331210632
#       3   3  36  36        -0.0331210632
#       1   1   8   8        -0.0302549308
#       2   3  27  36        -0.0236707615
#       3   2  36  27        -0.0236707615
#       1   2   8  27        -0.0219483746
#       2   1  27   8        -0.0219483746
#       1   3   8  36        -0.0219483746
#       3   1  36   8        -0.0219483746
#       0   2  11  27         0.0176262348
#
#     SCF energy       (wfn)                    = -128.496438392024714
#     Reference energy (file100)                = -128.496438392024658
#
#     Opposite-spin MP2 correlation energy      =   -0.150180638468284
#     Same-spin MP2 correlation energy          =   -0.056749958818434
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.206930597286718
#       * MP2 total energy                      = -128.703368989311372
#
#     Opposite-spin CCSD correlation energy     =   -0.157937017334002
#     Same-spin CCSD correlation energy         =   -0.052282185959844
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.210219203293846
#       * CCSD total energy                     = -128.706657595318489
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      RHF
#
#     Nuclear Rep. energy (wfn)                =    0.000000000000000
#     SCF energy          (wfn)                = -128.496438392024714
#     Reference energy    (file100)            = -128.496438392024658
#     CCSD energy         (file100)            =   -0.210219203293846
#     Total CCSD energy   (file100)            = -128.706657595318489
#
#     Number of ijk index combinations:               20
#     Memory available in words               :        65536000
#     Approx. words needed per explicit thread:           27436
#     Number of threads for explicit ijk threading:    1
#
#     MKL num_threads set to 1 for explicit threading.
#
#     (T) energy                                =   -0.002807365332066
#       * CCSD(T) total energy                  = -128.709464960650564
#
#
#        N-Body: Complex Energy (fragments = (2,), basis = (1, 2):  -128.70946496065056)
#
#        N-Body: Computing complex (2/2) with fragments (1,) in the basis of fragments (1, 2).
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
#
# *** tstart() called on rlyeh
# *** at Fri Sep 24 12:58:03 2021
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry NE         line   326 file /nix/store/rg166scwkb8v2jqk5yy7pmxfn5ywfm07-python3.9-psi4-1.4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2v
#     Full point group: C_inf_v
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          NE           0.000000000000     0.000000000000    -1.250000000000    19.992440176200
#       Gh(NE)          0.000000000000     0.000000000000     1.250000000000    19.992440176200
#
#   Running in c2v symmetry.
#
#   Rotational constants: A = ************  B =      0.26982  C =      0.26982 [cm^-1]
#   Rotational constants: A = ************  B =   8089.12176  C =   8089.12176 [MHz]
#   Nuclear repulsion =    0.000000000000000
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 10
#   Nalpha       = 5
#   Nbeta        = 5
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 18
#     Number of basis functions: 46
#     Number of Cartesian functions: 50
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              18
#       Number of primitives:             50
#       Number of atomic orbitals:        50
#       Number of basis functions:        46
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 1169642 doubles for integral storage.
#   We computed 14293 shell quartets total.
#   Whereas there are 14706 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 4.9925438186E-02.
#   Reciprocal condition number of the overlap matrix is 1.8240897792E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A1        22      22
#      A2         4       4
#      B1        10      10
#      B2        10      10
#    -------------------------
#     Total      46      46
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:  -128.49634722923187   -1.28496e+02   0.00000e+00
#    @RHF iter   1:  -128.49643645752928   -8.92283e-05   8.30689e-05 DIIS
#    @RHF iter   2:  -128.49643822809384   -1.77056e-06   2.89618e-05 DIIS
#    @RHF iter   3:  -128.49643838180117   -1.53707e-07   6.56837e-06 DIIS
#    @RHF iter   4:  -128.49643839196588   -1.01647e-08   3.46539e-07 DIIS
#    @RHF iter   5:  -128.49643839202403   -5.81508e-11   3.11884e-08 DIIS
#    @RHF iter   6:  -128.49643839202460   -5.68434e-13   5.10887e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A1   -32.794999     2A1    -1.940396     3A1    -0.853000
#        1B2    -0.852986     1B1    -0.852986
#
#     Virtual:
#
#        4A1     0.163586     2B2     0.242152     2B1     0.242152
#        5A1     0.248883     6A1     0.323039     3B2     0.332037
#        3B1     0.332037     7A1     0.493003     8A1     1.082205
#        4B1     1.312813     4B2     1.312813     9A1     1.319752
#       10A1     1.752522     1A2     1.757686    11A1     1.757686
#        5B1     1.761285     5B2     1.761285     6B2     1.968421
#        6B1     1.968421    12A1     1.976849    13A1     2.123769
#        2A2     2.123769     7B1     2.141738     7B2     2.141738
#       14A1     2.295077    15A1     2.845273    16A1     4.704755
#        3A2     6.372541    17A1     6.372541     8B2     6.378208
#        8B1     6.378208    18A1     6.421934     9B2     8.947897
#        9B1     8.947897     4A2     8.956409    19A1     8.956409
#       10B1     8.965727    10B2     8.965727    20A1     8.975407
#       21A1     9.018394    22A1    53.421735
#
#     Final Occupation by Irrep:
#              A1    A2    B1    B2
#     DOCC [     3,    0,    1,    1 ]
#
#   @RHF Final Energy:  -128.49643839202460
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =              0.0000000000000000
#     One-Electron Energy =                -182.4041421771295290
#     Two-Electron Energy =                  53.9077037851049425
#     Total Energy =                       -128.4964383920245723
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:   -23.6216
#
#   Electronic Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    23.6196
#
#   Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    -0.0019     Total:     0.0019
#
#   Dipole Moment: [D]
#      X:     0.0000      Y:     0.0000      Z:    -0.0049     Total:     0.0049
#
#
# *** tstop() called on rlyeh at Fri Sep 24 12:58:03 2021
# Module time:
# 	user time   =       0.25 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       6.10 seconds =       0.10 minutes
# 	system time =       2.55 seconds =       0.04 minutes
# 	total time  =        403 seconds =       6.72 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              18
#       Number of SO shells:              18
#       Number of primitives:             50
#       Number of atomic orbitals:        50
#       Number of basis functions:        46
#
#       Number of irreps:                  4
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  22    4   10   10 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 118972 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on rlyeh
# *** at Fri Sep 24 12:58:03 2021
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 4
# 	Number of MOs        = 46
# 	Number of active MOs = 45
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = RHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 A1	   22	    1	    2	    0	    19	    0
# 	 A2	   4	    0	    0	    0	    4	    0
# 	 B1	   10	    0	    1	    0	    9	    0
# 	 B2	   10	    0	    1	    0	    9	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =    -93.84889482771565
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.291 (MW) /      2.324 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.099 (MW) /      0.789 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.171 (MW) /      1.371 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.171 (MW) /      1.371 (MB)
# 	Total:                                     0.732 (MW) /      5.855 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.030 (MW) /      0.241 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.008 (MW) /      0.065 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.017 (MW) /      0.136 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.017 (MW) /      0.136 (MB)
# 	Total:                                     0.072 (MW) /      0.578 (MB)
#
# 	Size of irrep 0 of tijab amplitudes:       0.003 (MW) /      0.026 (MB)
# 	Size of irrep 1 of tijab amplitudes:       0.001 (MW) /      0.005 (MB)
# 	Size of irrep 2 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Size of irrep 3 of tijab amplitudes:       0.002 (MW) /      0.013 (MB)
# 	Total:                                     0.007 (MW) /      0.057 (MB)
#
# 	Nuclear Rep. energy          =      0.00000000000000
# 	SCF energy                   =   -128.49643839202460
# 	One-electron energy          =    -60.29634956360997
# 	Two-electron energy          =     25.64880599930116
# 	Reference energy             =   -128.49643839202446
#
# *** tstop() called on rlyeh at Fri Sep 24 12:58:03 2021
# Module time:
# 	user time   =       0.05 seconds =       0.00 minutes
# 	system time =       0.06 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       6.24 seconds =       0.10 minutes
# 	system time =       2.61 seconds =       0.04 minutes
# 	total time  =        403 seconds =       6.72 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =    0.000000000000000
#     SCF energy          (wfn)     = -128.496438392024601
#     Reference energy    (file100) = -128.496438392024459
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     RHF
#     Brueckner       =     No
#     Memory (Mbytes) =     524.3
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LOW
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.2069305972867189
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.206930597286719    0.000e+00    0.000000    0.000000    0.000000    0.082908
#      1        -0.207285299678085    2.745e-02    0.008612    0.013707    0.013707    0.083772
#      2        -0.209745655537152    7.158e-03    0.008273    0.013048    0.013048    0.085846
#      3        -0.210268981648080    2.789e-03    0.009277    0.014651    0.014651    0.086515
#      4        -0.210229328622422    3.565e-04    0.009387    0.014827    0.014827    0.086545
#      5        -0.210219912534434    8.554e-05    0.009406    0.014860    0.014860    0.086540
#      6        -0.210219561015234    2.015e-05    0.009410    0.014868    0.014868    0.086539
#      7        -0.210219318916592    6.022e-06    0.009411    0.014870    0.014870    0.086538
#      8        -0.210219215483386    1.220e-06    0.009411    0.014870    0.014870    0.086538
#      9        -0.210219206702633    2.695e-07    0.009411    0.014870    0.014870    0.086538
#     10        -0.210219203293847    6.279e-08    0.009411    0.014870    0.014870    0.086538
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#               1   2        -0.0125301020
#               2  24        -0.0115227303
#               3  33        -0.0115227303
#               2  23        -0.0088876790
#               3  32        -0.0088876790
#               1   0         0.0055067038
#               0   1         0.0050988277
#               0   3         0.0038389936
#               1   3         0.0038296769
#               1   1        -0.0031155877
#
#     Largest TIjAb Amplitudes:
#       2   2  27  27        -0.0331210632
#       3   3  36  36        -0.0331210632
#       1   1   8   8        -0.0302549308
#       2   3  27  36        -0.0236707615
#       3   2  36  27        -0.0236707615
#       1   2   8  27         0.0219483746
#       2   1  27   8         0.0219483746
#       1   3   8  36         0.0219483746
#       3   1  36   8         0.0219483746
#       0   2  11  27        -0.0176262348
#
#     SCF energy       (wfn)                    = -128.496438392024601
#     Reference energy (file100)                = -128.496438392024459
#
#     Opposite-spin MP2 correlation energy      =   -0.150180638468285
#     Same-spin MP2 correlation energy          =   -0.056749958818434
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.206930597286719
#       * MP2 total energy                      = -128.703368989311173
#
#     Opposite-spin CCSD correlation energy     =   -0.157937017334003
#     Same-spin CCSD correlation energy         =   -0.052282185959844
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.210219203293847
#       * CCSD total energy                     = -128.706657595318319
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      RHF
#
#     Nuclear Rep. energy (wfn)                =    0.000000000000000
#     SCF energy          (wfn)                = -128.496438392024601
#     Reference energy    (file100)            = -128.496438392024459
#     CCSD energy         (file100)            =   -0.210219203293847
#     Total CCSD energy   (file100)            = -128.706657595318319
#
#     Number of ijk index combinations:               20
#     Memory available in words               :        65536000
#     Approx. words needed per explicit thread:           27436
#     Number of threads for explicit ijk threading:    1
#
#     MKL num_threads set to 1 for explicit threading.
#
#     (T) energy                                =   -0.002807365332066
#       * CCSD(T) total energy                  = -128.709464960650365
#
#
#        N-Body: Complex Energy (fragments = (1,), basis = (1, 2):  -128.70946496065037)
#
#    ==> N-Body: Now computing 2-body complexes <==
#
#
#        N-Body: Computing complex (1/1) with fragments (1, 2) in the basis of fragments (1, 2).
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
#
# *** tstart() called on rlyeh
# *** at Fri Sep 24 12:58:03 2021
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry NE         line   326 file /nix/store/rg166scwkb8v2jqk5yy7pmxfn5ywfm07-python3.9-psi4-1.4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: d2h
#     Full point group: D_inf_h
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          NE           0.000000000000     0.000000000000    -1.250000000000    19.992440176200
#          NE           0.000000000000     0.000000000000     1.250000000000    19.992440176200
#
#   Running in d2h symmetry.
#
#   Rotational constants: A = ************  B =      0.26982  C =      0.26982 [cm^-1]
#   Rotational constants: A = ************  B =   8089.12176  C =   8089.12176 [MHz]
#   Nuclear repulsion =   21.167088426799999
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 20
#   Nalpha       = 10
#   Nbeta        = 10
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is PK.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 18
#     Number of basis functions: 46
#     Number of Cartesian functions: 50
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> Integral Setup <==
#
#   Using in-core PK algorithm.
#    Calculation information:
#       Number of atoms:                   2
#       Number of AO shells:              18
#       Number of primitives:             50
#       Number of atomic orbitals:        50
#       Number of basis functions:        46
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 1169642 doubles for integral storage.
#   We computed 14293 shell quartets total.
#   Whereas there are 14706 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 6.0017235992E-02.
#   Reciprocal condition number of the overlap matrix is 2.3099573039E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag        11      11
#      B1g        2       2
#      B2g        5       5
#      B3g        5       5
#      Au         2       2
#      B1u       11      11
#      B2u        5       5
#      B3u        5       5
#    -------------------------
#     Total      46      46
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:  -256.99497566013525   -2.56995e+02   0.00000e+00
#    @RHF iter   1:  -256.99143701287653    3.53865e-03   2.17417e-04 DIIS
#    @RHF iter   2:  -256.99144231343143   -5.30055e-06   9.03897e-05 DIIS
#    @RHF iter   3:  -256.99144317487264   -8.61441e-07   1.73203e-05 DIIS
#    @RHF iter   4:  -256.99144325168055   -7.68079e-08   2.34459e-06 DIIS
#    @RHF iter   5:  -256.99144325306474   -1.38419e-09   2.05011e-07 DIIS
#    @RHF iter   6:  -256.99144325307316   -8.41283e-12   2.68886e-08 DIIS
#    @RHF iter   7:  -256.99144325307350   -3.41061e-13   5.83918e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1B1u  -32.793625     1Ag   -32.793620     2Ag    -1.942031
#        2B1u   -1.937547     3Ag    -0.867552     1B3u   -0.854681
#        1B2u   -0.854681     1B2g   -0.849729     1B3g   -0.849729
#        3B1u   -0.837782
#
#     Virtual:
#
#        4B1u    0.259368     4Ag     0.262505     2B3u    0.267750
#        2B2u    0.267750     2B3g    0.346489     2B2g    0.346489
#        5Ag     0.355989     5B1u    0.545225     6Ag     1.613504
#        3B2u    1.722381     3B3u    1.722381     7Ag     1.754233
#        1B1g    1.754233     6B1u    1.761688     1Au     1.761688
#        3B2g    1.806614     3B3g    1.806614     7B1u    1.926596
#        4B2u    1.960934     4B3u    1.960934     4B3g    1.985296
#        4B2g    1.985296     8Ag     1.996255     8B1u    2.079002
#        9Ag     2.781432     9B1u    2.904554    10Ag     6.301197
#        5B2u    6.348019     5B3u    6.348019     2B1g    6.370739
#       11Ag     6.370739     2Au     6.375760    10B1u    6.375760
#        5B2g    6.410401     5B3g    6.410401    11B1u    6.557840
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     3,    0,    1,    1,    0,    3,    1,    1 ]
#
#   @RHF Final Energy:  -256.99144325307350
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             21.1670884267999995
#     One-Electron Energy =                -407.1551114761488179
#     Two-Electron Energy =                 128.9965797962753413
#     Total Energy =                       -256.9914432530734985
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    -0.0000
#
#   Electronic Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:     0.0000
#
#   Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:    -0.0000     Total:     0.0000
#
#   Dipole Moment: [D]
#      X:     0.0000      Y:     0.0000      Z:    -0.0000     Total:     0.0000
#
#
# *** tstop() called on rlyeh at Fri Sep 24 12:58:04 2021
# Module time:
# 	user time   =       0.27 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       6.63 seconds =       0.11 minutes
# 	system time =       2.77 seconds =       0.05 minutes
# 	total time  =        404 seconds =       6.73 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              18
#       Number of SO shells:               9
#       Number of primitives:             50
#       Number of atomic orbitals:        50
#       Number of basis functions:        46
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  11    2    5    5    2   11    5    5 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 69839 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on rlyeh
# *** at Fri Sep 24 12:58:04 2021
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 8
# 	Number of MOs        = 46
# 	Number of active MOs = 44
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = RHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   11	    1	    2	    0	    8	    0
# 	 B1g	   2	    0	    0	    0	    2	    0
# 	 B2g	   5	    0	    1	    0	    4	    0
# 	 B3g	   5	    0	    1	    0	    4	    0
# 	 Au	   2	    0	    0	    0	    2	    0
# 	 B1u	   11	    1	    2	    0	    8	    0
# 	 B2u	   5	    0	    1	    0	    4	    0
# 	 B3u	   5	    0	    1	    0	    4	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =   -195.31793590819362
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.040 (MW) /      0.320 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.016 (MW) /      0.131 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.026 (MW) /      0.205 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.026 (MW) /      0.205 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.016 (MW) /      0.131 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.040 (MW) /      0.320 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.026 (MW) /      0.205 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.026 (MW) /      0.205 (MB)
# 	Total:                                     0.215 (MW) /      1.721 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.010 (MW) /      0.077 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.003 (MW) /      0.025 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.006 (MW) /      0.046 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.006 (MW) /      0.046 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.003 (MW) /      0.025 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.010 (MW) /      0.077 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.006 (MW) /      0.046 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.006 (MW) /      0.046 (MB)
# 	Total:                                     0.048 (MW) /      0.387 (MB)
#
# 	Size of irrep 0 of tijab amplitudes:       0.002 (MW) /      0.019 (MB)
# 	Size of irrep 1 of tijab amplitudes:       0.001 (MW) /      0.004 (MB)
# 	Size of irrep 2 of tijab amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Size of irrep 3 of tijab amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Size of irrep 4 of tijab amplitudes:       0.001 (MW) /      0.004 (MB)
# 	Size of irrep 5 of tijab amplitudes:       0.002 (MW) /      0.019 (MB)
# 	Size of irrep 6 of tijab amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Size of irrep 7 of tijab amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Total:                                     0.011 (MW) /      0.088 (MB)
#
# 	Nuclear Rep. energy          =     21.16708842680000
# 	SCF energy                   =   -256.99144325307350
# 	One-electron energy          =   -147.69372939383561
# 	Two-electron energy          =     64.85313362215267
# 	Reference energy             =   -256.99144325307657
#
# *** tstop() called on rlyeh at Fri Sep 24 12:58:04 2021
# Module time:
# 	user time   =       0.05 seconds =       0.00 minutes
# 	system time =       0.07 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       6.74 seconds =       0.11 minutes
# 	system time =       2.84 seconds =       0.05 minutes
# 	total time  =        404 seconds =       6.73 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =   21.167088426799999
#     SCF energy          (wfn)     = -256.991443253073498
#     Reference energy    (file100) = -256.991443253076568
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     RHF
#     Brueckner       =     No
#     Memory (Mbytes) =     524.3
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LOW
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.4140130211828333
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
# ...
#
#       Integral cutoff                 1.00e-12
#       Number of threads:                 1
#
#   Performing in-core PK
#   Using 1169642 doubles for integral storage.
#   We computed 11155 shell quartets total.
#   Whereas there are 14706 unique shell quartets.
#
#   ==> DiskJK: Disk-Based J/K Matrices <==
#
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     Memory [MiB]:              375
#     Schwarz Cutoff:          1E-12
#
#     OpenMP threads:              1
#
#   Minimum eigenvalue in the overlap matrix is 9.3559134025E-02.
#   Reciprocal condition number of the overlap matrix is 4.2251898643E-02.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      Ag        11      11
#      B1g        2       2
#      B2g        5       5
#      B3g        5       5
#      Au         2       2
#      B1u       11      11
#      B2u        5       5
#      B3u        5       5
#    -------------------------
#     Total      46      46
#    -------------------------
#
#   ==> Iterations <==
#
#                         Total Energy        Delta E     RMS |[F,P]|
#
#    @RHF iter SAD:  -256.99270069033628   -2.56993e+02   0.00000e+00
#    @RHF iter   1:  -256.99270111739605   -4.27060e-07   1.10687e-04 DIIS
#    @RHF iter   2:  -256.99270198459652   -8.67200e-07   5.60544e-05 DIIS
#    @RHF iter   3:  -256.99270225004494   -2.65448e-07   1.02736e-06 DIIS
#    @RHF iter   4:  -256.99270225029460   -2.49656e-10   6.45051e-08 DIIS
#    @RHF iter   5:  -256.99270225029557   -9.66338e-13   8.40849e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1B1u  -32.794959     1Ag   -32.794958     2Ag    -1.940444
#        2B1u   -1.940414     3Ag    -0.853475     1B3u   -0.853096
#        1B2u   -0.853096     1B3g   -0.853000     1B2g   -0.853000
#        3B1u   -0.852618
#
#     Virtual:
#
#        4Ag     0.228954     2B2u    0.275314     2B3u    0.275314
#        4B1u    0.281360     5Ag     0.297619     2B2g    0.312836
#        2B3g    0.312836     5B1u    0.416139     6B1u    1.757119
#        6Ag     1.757236     3B3u    1.757644     3B2u    1.757644
#        3B3g    1.757666     3B2g    1.757666     1B1g    1.757687
#        7Ag     1.757687     7B1u    1.757688     1Au     1.757688
#        4B3u    1.949577     4B2u    1.949577     8Ag     1.952473
#        4B2g    1.975495     4B3g    1.975495     8B1u    2.016694
#        9Ag     2.721326     9B1u    2.796183     2B1g    6.372466
#       10Ag     6.372466     2Au     6.372466    10B1u    6.372466
#        5B3u    6.372503     5B2u    6.372503     5B2g    6.372513
#        5B3g    6.372513    11Ag     6.373136    11B1u    6.374103
#
#     Final Occupation by Irrep:
#              Ag   B1g   B2g   B3g    Au   B1u   B2u   B3u
#     DOCC [     3,    0,    1,    1,    0,    3,    1,    1 ]
#
#   @RHF Final Energy:  -256.99270225029557
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             13.2294302667499935
#     One-Electron Energy =                -391.2661472568188401
#     Two-Electron Energy =                 121.0440147397732460
#     Total Energy =                       -256.9927022502955651
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:     0.0000
#
#   Electronic Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:     0.0000
#
#   Dipole Moment: [e a0]
#      X:     0.0000      Y:     0.0000      Z:     0.0000     Total:     0.0000
#
#   Dipole Moment: [D]
#      X:     0.0000      Y:     0.0000      Z:     0.0000     Total:     0.0000
#
#
# *** tstop() called on rlyeh at Fri Sep 24 12:58:17 2021
# Module time:
# 	user time   =       0.24 seconds =       0.00 minutes
# 	system time =       0.00 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      15.81 seconds =       0.26 minutes
# 	system time =       7.21 seconds =       0.12 minutes
# 	total time  =        417 seconds =       6.95 minutes
#  MINTS: Wrapper to libmints.
#    by Justin Turney
#
#    Calculation information:
#       Number of threads:                 1
#       Number of atoms:                   2
#       Number of AO shells:              18
#       Number of SO shells:               9
#       Number of primitives:             50
#       Number of atomic orbitals:        50
#       Number of basis functions:        46
#
#       Number of irreps:                  8
#       Integral cutoff                 1.00e-12
#       Number of functions per irrep: [  11    2    5    5    2   11    5    5 ]
#
#  OEINTS: Overlap, kinetic, potential, dipole, and quadrupole integrals
#          stored in file 35.
#
#       Computing two-electron integrals...done
#       Computed 69839 non-zero two-electron integrals.
#         Stored in file 33.
#
#
# *** tstart() called on rlyeh
# *** at Fri Sep 24 12:58:17 2021
#
#
# 	Wfn Parameters:
# 	--------------------
# 	Wavefunction         = CCSD_T
# 	Number of irreps     = 8
# 	Number of MOs        = 46
# 	Number of active MOs = 44
# 	AO-Basis             = NONE
# 	Semicanonical        = false
# 	Reference            = RHF
# 	Print Level          = 1
#
# 	IRREP	# MOs	# FZDC	# DOCC	# SOCC	# VIRT	# FZVR
# 	-----	-----	------	------	------	------	------
# 	 Ag	   11	    1	    2	    0	    8	    0
# 	 B1g	   2	    0	    0	    0	    2	    0
# 	 B2g	   5	    0	    1	    0	    4	    0
# 	 B3g	   5	    0	    1	    0	    4	    0
# 	 Au	   2	    0	    0	    0	    2	    0
# 	 B1u	   11	    1	    2	    0	    8	    0
# 	 B2u	   5	    0	    1	    0	    4	    0
# 	 B3u	   5	    0	    1	    0	    4	    0
# 	Transforming integrals...
# 	IWL integrals will be deleted.
# 	(OO|OO)...
# 	Presorting SO-basis two-electron integrals.
# 	Sorting File: SO Ints (nn|nn) nbuckets = 1
# 	Constructing frozen core operators
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OO|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(OV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OO)...
# 	Starting first half-transformation.
# 	Sorting half-transformed integrals.
# 	First half integral transformation complete.
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|OV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	(VV|VV)...
# 	Starting second half-transformation.
# 	Two-electron integral transformation complete.
# 	Frozen core energy     =   -192.46039626012501
#
# 	Size of irrep 0 of <ab|cd> integrals:      0.040 (MW) /      0.320 (MB)
# 	Size of irrep 1 of <ab|cd> integrals:      0.016 (MW) /      0.131 (MB)
# 	Size of irrep 2 of <ab|cd> integrals:      0.026 (MW) /      0.205 (MB)
# 	Size of irrep 3 of <ab|cd> integrals:      0.026 (MW) /      0.205 (MB)
# 	Size of irrep 4 of <ab|cd> integrals:      0.016 (MW) /      0.131 (MB)
# 	Size of irrep 5 of <ab|cd> integrals:      0.040 (MW) /      0.320 (MB)
# 	Size of irrep 6 of <ab|cd> integrals:      0.026 (MW) /      0.205 (MB)
# 	Size of irrep 7 of <ab|cd> integrals:      0.026 (MW) /      0.205 (MB)
# 	Total:                                     0.215 (MW) /      1.721 (MB)
#
# 	Size of irrep 0 of <ia|bc> integrals:      0.010 (MW) /      0.077 (MB)
# 	Size of irrep 1 of <ia|bc> integrals:      0.003 (MW) /      0.025 (MB)
# 	Size of irrep 2 of <ia|bc> integrals:      0.006 (MW) /      0.046 (MB)
# 	Size of irrep 3 of <ia|bc> integrals:      0.006 (MW) /      0.046 (MB)
# 	Size of irrep 4 of <ia|bc> integrals:      0.003 (MW) /      0.025 (MB)
# 	Size of irrep 5 of <ia|bc> integrals:      0.010 (MW) /      0.077 (MB)
# 	Size of irrep 6 of <ia|bc> integrals:      0.006 (MW) /      0.046 (MB)
# 	Size of irrep 7 of <ia|bc> integrals:      0.006 (MW) /      0.046 (MB)
# 	Total:                                     0.048 (MW) /      0.387 (MB)
#
# 	Size of irrep 0 of tijab amplitudes:       0.002 (MW) /      0.019 (MB)
# 	Size of irrep 1 of tijab amplitudes:       0.001 (MW) /      0.004 (MB)
# 	Size of irrep 2 of tijab amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Size of irrep 3 of tijab amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Size of irrep 4 of tijab amplitudes:       0.001 (MW) /      0.004 (MB)
# 	Size of irrep 5 of tijab amplitudes:       0.002 (MW) /      0.019 (MB)
# 	Size of irrep 6 of tijab amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Size of irrep 7 of tijab amplitudes:       0.001 (MW) /      0.010 (MB)
# 	Total:                                     0.011 (MW) /      0.088 (MB)
#
# 	Nuclear Rep. energy          =     13.22943026674999
# 	SCF energy                   =   -256.99270225029557
# 	One-electron energy          =   -137.52518940132242
# 	Two-electron energy          =     59.76345314440100
# 	Reference energy             =   -256.99270225029647
#
# *** tstop() called on rlyeh at Fri Sep 24 12:58:17 2021
# Module time:
# 	user time   =       0.04 seconds =       0.00 minutes
# 	system time =       0.06 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      15.91 seconds =       0.27 minutes
# 	system time =       7.28 seconds =       0.12 minutes
# 	total time  =        417 seconds =       6.95 minutes
#             **************************
#             *                        *
#             *        CCENERGY        *
#             *                        *
#             **************************
#
#     Nuclear Rep. energy (wfn)     =   13.229430266749993
#     SCF energy          (wfn)     = -256.992702250295565
#     Reference energy    (file100) = -256.992702250296475
#
#     Input parameters:
#     -----------------
#     Wave function   =     CCSD_T
#     Reference wfn   =     RHF
#     Brueckner       =     No
#     Memory (Mbytes) =     524.3
#     Maxiter         =     50
#     R_Convergence   =     1.0e-07
#     E_Convergence   =     1.0e-06
#     Restart         =     Yes
#     DIIS            =     Yes
#     AO Basis        =     NONE
#     ABCD            =     NEW
#     Cache Level     =     2
#     Cache Type      =     LOW
#     Print Level     =     1
#     Num. of threads =     1
#     # Amps to Print =     10
#     Print MP2 Amps? =     No
#     Analyze T2 Amps =     No
#     Print Pair Ener =     No
#     Local CC        =     No
#     SCS-MP2         =     False
#     SCSN-MP2        =     False
#     SCS-CCSD        =     False
#
# MP2 correlation energy -0.4138144359100481
#                 Solving CC Amplitude Equations
#                 ------------------------------
#   Iter             Energy              RMS        T1Diag      D1Diag    New D1Diag    D2Diag
#   ----     ---------------------    ---------   ----------  ----------  ----------   --------
#      0        -0.413814435910048    0.000e+00    0.000000    0.000000    0.000000    0.082956
#      1        -0.414529757743896    3.876e-02    0.008598    0.014358    0.014358    0.083820
#      2        -0.419436952246256    1.009e-02    0.008259    0.013686    0.013686    0.085901
#      3        -0.420480611029052    3.935e-03    0.009263    0.015469    0.015469    0.086573
#      4        -0.420398827139715    4.945e-04    0.009374    0.015660    0.015660    0.086603
#      5        -0.420381028614376    1.096e-04    0.009392    0.015710    0.015710    0.086599
#      6        -0.420380472711510    2.244e-05    0.009396    0.015718    0.015718    0.086598
#      7        -0.420379929740267    6.109e-06    0.009397    0.015721    0.015721    0.086597
#      8        -0.420379770039373    1.131e-06    0.009397    0.015721    0.015721    0.086597
#      9        -0.420379768423831    2.706e-07    0.009397    0.015721    0.015721    0.086597
#     10        -0.420379761347007    6.741e-08    0.009397    0.015721    0.015721    0.086597
#
#     Iterations converged.
#
#
#     Largest TIA Amplitudes:
#               6  28        -0.0147036711
#               7  32        -0.0147036711
#               2  10        -0.0143467927
#               3  14        -0.0143467927
#               1   0         0.0118818794
#               5  21         0.0111221583
#               1   1        -0.0097870343
#               5  20        -0.0078441850
#               4  20         0.0056403247
#               0   1         0.0050106639
#
#     Largest TIjAb Amplitudes:
#       2   2  34  34        -0.0170191141
#       3   3  30  30        -0.0170191141
#       6   6  30  30        -0.0170123734
#       7   7  34  34        -0.0170123734
#       5   5   4   4        -0.0169030667
#       1   1   4   4        -0.0168581204
#       2   7  12  34        -0.0168488323
#       3   6  16  30        -0.0168488323
#       6   3  30  16        -0.0168488323
#       7   2  34  12        -0.0168488323
#
#     SCF energy       (wfn)                    = -256.992702250295565
#     Reference energy (file100)                = -256.992702250296475
#
#     Opposite-spin MP2 correlation energy      =   -0.300317363199278
#     Same-spin MP2 correlation energy          =   -0.113497072710770
#     Singles MP2 correlation energy            =   -0.000000000000000
#     MP2 correlation energy                    =   -0.413814435910048
#       * MP2 total energy                      = -257.406516686206544
#
#     Opposite-spin CCSD correlation energy     =   -0.315821617740254
#     Same-spin CCSD correlation energy         =   -0.104558143606753
#     Singles CCSD correlation energy           =    0.000000000000000
#     CCSD correlation energy                   =   -0.420379761347007
#       * CCSD total energy                     = -257.413082011643496
#
#             **************************
#             *                        *
#             *        CCTRIPLES       *
#             *                        *
#             **************************
#
#
#     Wave function   =    CCSD_T
#     Reference wfn   =      RHF
#
#     Nuclear Rep. energy (wfn)                =   13.229430266749993
#     SCF energy          (wfn)                = -256.992702250295565
#     Reference energy    (file100)            = -256.992702250296475
#     CCSD energy         (file100)            =   -0.420379761347007
#     Total CCSD energy   (file100)            = -257.413082011643496
#
#     Number of ijk index combinations:              120
#     Memory available in words               :        65536000
#     Approx. words needed per explicit thread:            2048
#     Number of threads for explicit ijk threading:    1
#
#     MKL num_threads set to 1 for explicit threading.
#
#     (T) energy                                =   -0.005592021139469
#       * CCSD(T) total energy                  = -257.418674032782974
#
#
#        N-Body: Complex Energy (fragments = (1, 2), basis = (1, 2):  -257.41867403278297)
#
#    ==> N-Body: Counterpoise Corrected (CP) energies <==
#
#    n-Body     Total Energy [Eh]       I.E. [kcal/mol]      Delta [kcal/mol]
#         1                   N/A        0.000000000000        0.000000000000
#         2                   N/A       -0.016266002393       -0.016266002393
#
#    => Loading Basis Set <=
#
#     Name: DEF2-SVP
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry NE         line   170 file /nix/store/rg166scwkb8v2jqk5yy7pmxfn5ywfm07-python3.9-psi4-1.4/share/psi4/basis/def2-svp.gbs

# %%
# %matplotlib inline
x = np.linspace(0, 10, 100)

plt.plot(*zip(*ecp.items()))

plt.show()
